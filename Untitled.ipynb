# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('OnlineRetail.csv', encoding='latin1')
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

data['InvoiceYearMonth'] = data['InvoiceDate'].map(lambda date: 100*date.year + date.month)
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country  InvoiceYearMonth
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom            201012
# ...

# %%
data['Revenue'] = data['UnitPrice'] * data['Quantity']
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...

# %%
tx_revenue = data.groupby(['InvoiceYearMonth'])['Revenue'].sum().reset_index()
tx_revenue
# Out:
#     InvoiceYearMonth      Revenue
# 0             201012   748957.020
# 1             201101   560000.260
# 2             201102   498062.650
# 3             201103   683267.080
# 4             201104   493207.121
# 5             201105   723333.510
# 6             201106   691123.120
# 7             201107   681300.111
# 8             201108   682680.510
# 9             201109  1019687.622
# 10            201110  1070704.670
# 11            201111  1461756.250
# 12            201112   433668.010

# %%
plt.figure(figsize=(12, 6))
plt.plot(tx_revenue['InvoiceYearMonth'].to_numpy(dtype=str), tx_revenue['Revenue'], marker='o')
plt.grid()
plt.title('Montly Revenue')
# Out:
# Text(0.5, 1.0, 'Montly Revenue')

# %%
tx_revenue['MonthlyGrowth'] = tx_revenue['Revenue'].pct_change()
tx_revenue
# Out:
#     InvoiceYearMonth      Revenue  MonthlyGrowth
# 0             201012   748957.020            NaN
# 1             201101   560000.260      -0.252293
# 2             201102   498062.650      -0.110603
# 3             201103   683267.080       0.371850
# 4             201104   493207.121      -0.278163
# 5             201105   723333.510       0.466592
# 6             201106   691123.120      -0.044530
# 7             201107   681300.111      -0.014213
# 8             201108   682680.510       0.002026
# 9             201109  1019687.622       0.493653
# 10            201110  1070704.670       0.050032
# 11            201111  1461756.250       0.365228
# 12            201112   433668.010      -0.703324

# %%
plt.figure(figsize = (12, 6))
plt.plot(tx_revenue['InvoiceYearMonth'].to_numpy(dtype=str), tx_revenue['MonthlyGrowth'], marker='o')
plt.grid()

# %%
tx_uk = data.query("Country == 'United Kingdom'").reset_index(drop = True)

tx_monthly_active = tx_uk.groupby(['InvoiceYearMonth'])['CustomerID'].nunique().reset_index()
tx_monthly_active
# Out:
#     InvoiceYearMonth  CustomerID
# 0             201012         871
# 1             201101         684
# 2             201102         714
# 3             201103         923
# 4             201104         817
# 5             201105         985
# 6             201106         943
# 7             201107         899
# 8             201108         867
# 9             201109        1177
# 10            201110        1285
# 11            201111        1548
# 12            201112         617

# %%
plt.figure(figsize=(12, 6))
plt.bar(tx_revenue['InvoiceYearMonth'].to_numpy(dtype=str), tx_monthly_active['CustomerID'])
plt.grid(axis='y')

# %%
tx_monthly_sales = tx_uk.groupby(['InvoiceYearMonth'])['Quantity'].sum().reset_index()
tx_monthly_sales
# Out:
#     InvoiceYearMonth  Quantity
# 0             201012    298101
# 1             201101    237381
# 2             201102    225641
# 3             201103    279843
# 4             201104    257666
# 5             201105    306452
# 6             201106    258522
# 7             201107    324129
# 8             201108    319804
# 9             201109    458490
# 10            201110    455612
# 11            201111    642281
# 12            201112    199907

# %%
plt.figure(figsize=(12,6))
plt.bar(tx_revenue['InvoiceYearMonth'].to_numpy(dtype=str), tx_monthly_sales['Quantity'])
plt.grid(axis='y')

# %%
tx_monthly_order_avg = tx_uk.groupby('InvoiceYearMonth')['Revenue'].mean().reset_index()
tx_monthly_order_avg
# Out:
#     InvoiceYearMonth    Revenue
# 0             201012  16.865860
# 1             201101  13.614680
# 2             201102  16.093027
# 3             201103  16.716166
# 4             201104  15.773380
# 5             201105  17.713823
# 6             201106  16.714748
# 7             201107  15.723497
# 8             201108  17.315899
# 9             201109  18.931723
# 10            201110  16.093582
# 11            201111  16.312383
# 12            201112  16.247406

# %%
plt.figure(figsize=(12,6))
plt.bar(tx_revenue['InvoiceYearMonth'].to_numpy(dtype=str), tx_monthly_order_avg['Revenue'])
plt.grid(axis='y')
